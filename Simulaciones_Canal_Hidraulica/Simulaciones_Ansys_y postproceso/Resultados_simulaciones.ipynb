# %%
import os
import pandas as pd

def load_data_from_folder(folder_path):
    # List all files in the folder
    files = [f for f in os.listdir(folder_path) if f.endswith(".txt") or f.endswith(".csv") or f.endswith(".out")]
    
    # Initialize an empty dictionary to store data
    data_dict = {}
    
    # Loop through each file
    for file in files:
        file_path = os.path.join(folder_path, file)
        
        # Read the file, assuming space-separated values, skipping the first two rows
        df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
        
        # Check if the expected number of columns exist
        if df.shape[1] < 3:
            raise ValueError(f"File {file} does not have the expected number of columns")
        
        # Extract column name from the second column of the third row
        column_name = os.path.splitext(file)[0].replace('-rfile', '')  # Use the file name (without extension) as the column name
        
        # Store the "Time Step" and "flow-time" only once
        if "Time Step" not in data_dict:
            data_dict["Time Step"] = df.iloc[:, 0]  # First column is "Time Step"
            data_dict["flow-time"] = df.iloc[:, 2]  # Third column is "flow-time"

        # Store the unique data column using the file name as the column name
        data_dict[column_name] = df.iloc[:, 1]  # Second column is the datum
    
    # Convert the dictionary to a DataFrame
    final_df = pd.DataFrame(data_dict)
    # Delete the first row of the DataFrame
    final_df = final_df.drop(index=0)
    
    # Convert all columns to double (float) type
    final_df = final_df.astype(float)
    
    return final_df

# Example usage

folder_path = "TSR_1"  # Change this to the actual folder path
df_1 = load_data_from_folder(folder_path)

folder_path = "TSR 0.8"  # Change this to the actual folder path
df_08 = load_data_from_folder(folder_path)

folder_path = "TSR_06"  # Change this to the actual folder path
df_06 = load_data_from_folder(folder_path)

folder_path = "TSR_0.4"  # Change this to the actual folder path
df_04 = load_data_from_folder(folder_path)

print(df_08)
# Out:
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
#       Time Step  flow-time          cd         cl        cm          fd  \
# 1           0.0       0.00    0.000000   0.000000  0.000000    0.000000
# 2           1.0       0.01  151.686607  14.424268  0.413259  174.769116
# 3           2.0       0.02    1.125078   6.945115 -0.038385    1.296284
# 4           3.0       0.03    0.397874   7.092581 -0.047938    0.458419
# 5           4.0       0.04    0.860720   6.915567 -0.075157    0.991698
# ...         ...        ...         ...        ...       ...         ...
# 1997     1996.0      19.96    0.648546   6.506008  0.185914    0.747237
# 1998     1997.0      19.97    0.642290   6.502588  0.186272    0.740029
# 1999     1998.0      19.98    0.657418   6.479622  0.192906    0.757459
# 2000     1999.0      19.99    0.645137   6.448020  0.192894    0.743309
# 2001     2000.0      20.00    0.655440   6.401320  0.203984    0.755180
#
#              fl         m
# 1      0.000000  0.000000
# 2     16.619243  0.081421
# 3      8.001969 -0.007563
# 4      8.171875 -0.009445
# 5      7.967925 -0.014808
# ...         ...       ...
# 1997   7.496043  0.036629
# 1998   7.492102  0.036700
# 1999   7.465641  0.038007
# 2000   7.429231  0.038004
# 2001   7.375424  0.040189
#
# [2001 rows x 8 columns]
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)
# C:\Users\nicoa\AppData\Local\Temp\ipykernel_17620\1595395108.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, skiprows=2, header=None)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_polar(df, RPM):

    # Determine k as the index for one revolution before the end
    w = RPM * np.pi / 30
    time_per_revolution = 2 * np.pi / w
    k = len(df) - int(time_per_revolution / (df["flow-time"][1] - df["flow-time"][0]))

    # Plot Time Step vs cl, cd, cm
    plt.figure()
    plt.plot(df["flow-time"][k:], df["fl"][k:], label='fl')
    plt.plot(df["flow-time"][k:], df["fd"][k:], label='fd')
    plt.plot(df["flow-time"][k:], df["m"][k:], label='m')
    plt.xlabel('Tiempo [s]')
    plt.ylabel('Coeficiente Adimencional')
    plt.title("Coeficientes adimensionales vs Tiempo")
    plt.legend()
    plt.show()

    # Calculate Theta
    w = RPM * np.pi / 30
    df["Theta"] = df["flow-time"] * w+np.pi/2
    k = 2

    # Crear subplots polares
    fig, axs = plt.subplots(1, 3, subplot_kw={'polar': True}, figsize=(15, 10))

    # Polar plot of Theta vs cl
    axs[0].plot(df["Theta"][k:], df["fl"][k:])
    axs[0].set_xlabel('Theta')
    #axs[0].set_ylabel('cl')
    axs[0].set_title('Polar Theta vs Cl\n')

    # Polar plot of Theta vs cd
    axs[1].plot(df["Theta"][k:], df["fd"][k:])
    axs[1].set_xlabel('Theta')
    #axs[1].set_ylabel('cd')
    axs[1].set_title('Polar Theta vs Cd\n')

    # Polar plot of Theta vs cm
    axs[2].plot(df["Theta"][k:], df["m"][k:])
    axs[2].set_xlabel('Theta')
    #axs[2].set_ylabel('cm')
    axs[2].set_title('Polar  Theta vs Cm\n')

    plt.tight_layout()
    plt.show()


def plot_polar_adim(df, RPM, k=10):
    adim=0.215/(0.171/2)
    # Plot Time Step vs cl, cd, cm
    plt.figure()
    plt.plot(df["flow-time"][k:]*adim, df["cl"][k:], label='Cl')
    plt.plot(df["flow-time"][k:]*adim, df["cd"][k:], label='Cd')
    plt.plot(df["flow-time"][k:]*adim, df["cm"][k:], label='Cm')
    plt.xlabel('Tiempo adimensional')
    plt.ylabel('Coeficiente Adimencional')
    plt.title("Coeficientes adimensionales vs Tiempo")
    plt.legend()
    plt.show()

    # Calculate Theta
    w = RPM * np.pi / 30
    df["Theta"] = df["flow-time"] * w+np.pi/2
    f = RPM/60
    T = 1/f
    k = len(df["flow-time"]) - int(T /0.01)

    # Crear subplots polares
    fig, axs = plt.subplots(1, 3, subplot_kw={'polar': True}, figsize=(15, 10))

    # Polar plot of Theta vs cl
    axs[0].plot(df["Theta"][k:], df["cl"][k:])
    axs[0].set_xlabel('Theta')
    #axs[0].set_ylabel('cl')
    axs[0].set_title('Polar Theta vs Cl\n')

    # Polar plot of Theta vs cd
    axs[1].plot(df["Theta"][k:], df["cd"][k:])
    axs[1].set_xlabel('Theta')
    #axs[1].set_ylabel('cd')
    axs[1].set_title('Polar Theta vs Cd\n')

    # Polar plot of Theta vs cm
    axs[2].plot(df["Theta"][k:], df["cm"][k:])
    axs[2].set_xlabel('Theta')
    #axs[2].set_ylabel('cm')
    axs[2].set_title('Polar  Theta vs Cm\n')

    plt.tight_layout()
    plt.show()

# %%
plot_polar_adim(df_1, RPM=13.961)

# %%
plot_polar_adim(df_08, RPM=11.1688)

# %%
plot_polar_adim(df_04, RPM=5.5848)

# %%
plot_polar_adim(df_06, RPM=8.3766)

# %%
from scipy.interpolate import splrep, splev

def calculate_rms(data):
    return np.sqrt(np.mean(np.square(data)))
    #return np.mean(data)
k=int(2/0.01)

df_rm= pd.DataFrame(columns=['TSR', 'RPM', 'cl_rms', 'cd_rms', 'cm_rms'])
df_rm.loc[0] = [0.8, 11.1688, calculate_rms(df_08['cl'][k:]), calculate_rms(df_08['cd'][k:]), calculate_rms(df_08['cm'][k:])] 
df_rm.loc[1] = [0.6, 8.3766, calculate_rms(df_06['cl'][k:]), calculate_rms(df_06['cd'][k:]), calculate_rms(df_06['cm'][k:])]
df_rm.loc[2] = [0.4, 5.5848, calculate_rms(df_04['cl'][k:]), calculate_rms(df_04['cd'][k:]), calculate_rms(df_04['cm'][k:])]
df_rm.loc[3] = [1.0, 13.961, calculate_rms(df_1['cl'][k:]), calculate_rms(df_1['cd'][k:]), calculate_rms(df_1['cm'][k:])]
df_rm["Cp_rms"]=df_rm["TSR"]*df_rm["cm_rms"]
print(df_rm)   

#Datos paper
Cp_paper = [0.005, 0.04, 0.19, 0.13, 0.1]
TSR = [1.2, 1, 0.8, 0.6, 0.4]

# Interpolación polinómica para los datos de simulación
degree = 3  # Grado del polinomio
coefficients_sim = np.polyfit(df_rm["TSR"], df_rm["Cp_rms"], degree)
polynomial_sim = np.poly1d(coefficients_sim)
TSR_interpolated_sim = np.linspace(min(df_rm["TSR"]), max(df_rm["TSR"]), 100)
Cp_interpolated_sim = polynomial_sim(TSR_interpolated_sim)

# Gráfico
plt.plot(df_rm["TSR"], df_rm["Cp_rms"], 'o', label="Simulación superficie libre")
plt.plot(TSR, Cp_paper, 'r:^', label="Patel")
plt.plot(TSR_interpolated_sim, Cp_interpolated_sim, '-', label="Interpolación polinómica simulación")
plt.title('Cp vs TSR')  
plt.xlabel('TSR')
plt.ylabel('Cp')
plt.legend()
plt.grid()
plt.show()
# Out:
#    TSR      RPM     cl_rms    cd_rms    cm_rms    Cp_rms
# 0  0.8  11.1688   6.564588  1.806207  0.176155  0.140924
# 1  0.6   8.3766   6.982875  1.796814  0.182784  0.109671
# 2  0.4   5.5848  10.778897  2.480571  0.294339  0.117735
# 3  1.0  13.9610   6.325745  1.692389  0.175511  0.175511

# %%
from scipy.interpolate import splrep, splev

def calculate_mean(data):
    return np.mean(data)

# Function to calculate the index for the last two periods
def get_last_two_periods_index(df, RPM):
    f = RPM/60
    T = 1/f
    k = len(df["flow-time"]) - int(T /0.01)
    return k

# Calculate the index for the last two periods for each dataset
k_08 = get_last_two_periods_index(df_08, 11.1688)
k_06 = get_last_two_periods_index(df_06, 8.3766)
k_04 = get_last_two_periods_index(df_04, 5.5848)
k_1 = get_last_two_periods_index(df_1, 13.961)

# Create the DataFrame with mean values
df_rm = pd.DataFrame(columns=['TSR', 'RPM', 'cl_mean', 'cd_mean', 'cm_mean'])
df_rm.loc[0] = [0.8, 11.1688, calculate_mean(df_08['cl'][k_08:]), calculate_mean(df_08['cd'][k_08:]), calculate_mean(df_08['cm'][k_08:])]
df_rm.loc[1] = [0.6, 8.3766, calculate_mean(df_06['cl'][k_06:]), calculate_mean(df_06['cd'][k_06:]), calculate_mean(df_06['cm'][k_06:])]
df_rm.loc[2] = [0.4, 5.5848, calculate_mean(df_04['cl'][k_04:]), calculate_mean(df_04['cd'][k_04:]), calculate_mean(df_04['cm'][k_04:])]
df_rm.loc[3] = [1.0, 13.961, calculate_mean(df_1['cl'][k_1:]), calculate_mean(df_1['cd'][k_1:]), calculate_mean(df_1['cm'][k_1:])]
df_rm["Cp_mean"] = df_rm["TSR"] * df_rm["cm_mean"]
print(df_rm)

# Datos paper
Cp_paper = [0.005, 0.04, 0.19, 0.13, 0.1]
TSR = [1.2, 1, 0.8, 0.6, 0.4]

# Interpolación polinómica para los datos de simulación
degree = 3  # Grado del polinomio
coefficients_sim = np.polyfit(df_rm["TSR"], df_rm["Cp_mean"], degree)
polynomial_sim = np.poly1d(coefficients_sim)
TSR_interpolated_sim = np.linspace(min(df_rm["TSR"]), max(df_rm["TSR"]), 100)
Cp_interpolated_sim = polynomial_sim(TSR_interpolated_sim)

# Gráfico
plt.plot(df_rm["TSR"], df_rm["Cp_mean"], 'o', label="Simulación superficie libre")
plt.plot(TSR, Cp_paper, 'r:^', label="Patel")
plt.plot(TSR_interpolated_sim, Cp_interpolated_sim, '-', label="Interpolación polinómica simulación")
plt.title('Cp vs TSR')  
plt.xlabel('TSR')
plt.ylabel('Cp')
plt.legend()
plt.grid()
plt.show()
# Polynomial interpolation for cl_mean
degree = 3
coefficients_cl = np.polyfit(df_rm["TSR"], df_rm["cl_mean"], degree)
polynomial_cl = np.poly1d(coefficients_cl)
TSR_interpolated_cl = np.linspace(min(df_rm["TSR"]), max(df_rm["TSR"]), 100)
Cl_interpolated = polynomial_cl(TSR_interpolated_cl)

# Polynomial interpolation for cd_mean
coefficients_cd = np.polyfit(df_rm["TSR"], df_rm["cd_mean"], degree)
polynomial_cd = np.poly1d(coefficients_cd)
TSR_interpolated_cd = np.linspace(min(df_rm["TSR"]), max(df_rm["TSR"]), 100)
Cd_interpolated = polynomial_cd(TSR_interpolated_cd)

# Polynomial interpolation for cm_mean
coefficients_cm = np.polyfit(df_rm["TSR"], df_rm["cm_mean"], degree)
polynomial_cm = np.poly1d(coefficients_cm)
TSR_interpolated_cm = np.linspace(min(df_rm["TSR"]), max(df_rm["TSR"]), 100)
Cm_interpolated = polynomial_cm(TSR_interpolated_cm)


plt.plot(df_rm["TSR"], df_rm["cl_mean"], 'o', label="Simulación superficie libre")
plt.plot(df_rm["TSR"], df_rm["cd_mean"], 'o', label="Simulación superficie libre")
plt.plot(df_rm["TSR"], df_rm["cm_mean"], 'o', label="Simulación superficie libre")
plt.plot(TSR_interpolated_cl, Cl_interpolated, '-', label="Interpolación polinómica cl")
plt.plot(TSR_interpolated_cd, Cd_interpolated, '-', label="Interpolación polinómica cd")
plt.plot(TSR_interpolated_cm, Cm_interpolated, '-', label="Interpolación polinómica cm")
plt.title('Coeficientes adimensionales vs TSR')
plt.xlabel('TSR')
plt.ylabel('Coeficientes adimensionales')
plt.legend()
plt.grid()
# Out:
#    TSR      RPM    cl_mean   cd_mean   cm_mean   Cp_mean
# 0  0.8  11.1688   6.488489  1.673412  0.161259  0.129007
# 1  0.6   8.3766   7.012507  1.622872  0.165222  0.099133
# 2  0.4   5.5848  10.937404  2.381539  0.275497  0.110199
# 3  1.0  13.9610   6.261091  1.595192  0.135734  0.135734
